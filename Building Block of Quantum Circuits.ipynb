# %%
from qiskit import *
import matplotlib.pyplot
from qiskit.tools.visualization import plot_bloch_multivector
from qiskit.tools.visualization import plot_histogram
import time

# %%
st = time.time()
circuit = QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend = simulator).result()
statevector = result.get_statevector()
print(statevector)
et = time.time()
time_taken = float(et-st)
print("\n")
print("Time taken for simulating: ",time_taken)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
#
#
# Time taken for simulating:  0.010191202163696289

# %%
# %matplotlib inline
circuit.draw(output='mpl')

# %%
plot_bloch_multivector(statevector)    # operations on quantum state is rotation in the Bloch Sphere

# %%
circuit.measure([0], [0])
backend = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=backend, shots=1024).result()
counts = result.get_counts()
plot_histogram(counts)

# %%
# Matrix Representation of a spin-flipping quantum circuit

st = time.time()
circuit = QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('unitary_simulator')
result = execute(circuit, backend = simulator).result()
unitary = result.get_unitary()
print(unitary)
et = time.time()
time_taken = float(et-st)
print("\n")
print("Time taken for simulating: ",time_taken)
# Out:
# Operator([[0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))
#
#
# Time taken for simulating:  0.008916139602661133
